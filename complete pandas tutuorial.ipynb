# %% [markdown]
# # Complete Pandas Tutorial

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\sarad\OneDrive\Desktop\CODE\PYTHON\Data Science\pokemon_data.csv")


# df.head()
# df.iloc[3,2]
# df.loc[df['HP']>100]
# for index,row in df.iterrows():
#     print(index,row)
# df.describe()
# df.sort_values("Name",ascending=False)
# df.HP.count()
# df.sort_values(['Type 1','HP'],ascending=True)
# df.sort_values(['Speed','Generation'],ascending=[1,1])

# %% [markdown]
# Making Changes To Data

# %%
#adding Columns
        # df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
#Dropping columns
        # df.drop(columns=['Total'],inplace=True)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.to_csv('modified.csv')

# %% [markdown]
# # Filtering Data

# %%
df.loc[df['Type 1']=='Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
newdf = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]
newdf.to_csv('conditional_pandas.csv')

# %%
#filtering data which has name mega
df.loc[df['Name'].str.contains('Mega')]
#deleting data which has name mega
df.loc[~df['Name'].str.contains('Mega')]
df.head()
#filtering data which has name mega
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %% [markdown]
# # Conditional Changes

# %%
df.loc[df['Type 1']=='Fire','Type 1']='Vamsi'
df.head(10)
df.loc[df['HP']>50, ['Name','Type 2']]=['Charmander','KVN']
df.head(30)
# Out:
#      #        Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1   Bulbasaur   Grass  Poison  45      49       49       65       65
# 1    2  Charmander   Grass     KVN  60      62       63       80       80
# 2    3  Charmander   Grass     KVN  80      82       83      100      100
# 3    3  Charmander   Grass     KVN  80     100      123      122      120
# 4    4  Charmander   Vamsi     NaN  39      52       43       60       50
# 5    5  Charmander   Vamsi     KVN  58      64       58       80       65
# 6    6  Charmander   Vamsi     KVN  78      84       78      109       85
# 7    6  Charmander   Vamsi     KVN  78     130      111      130       85
# 8    6  Charmander   Vamsi     KVN  78     104       78      159      115
# 9    7    Squirtle   Water     NaN  44      48       65       50       64
# 10   8  Charmander   Water     KVN  59      63       80       65       80
# 11   9  Charmander   Water     KVN  79      83      100       85      105
# ...
