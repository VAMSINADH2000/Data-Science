# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('train1.csv')
df2 = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Age"].fillna(df.groupby("Pclass")["Age"].transform("median"), inplace=True)
df2["Age"].fillna(df2.groupby("Pclass")["Age"].transform("median"), inplace=True)

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df2['Fare'].fillna(df2.Fare.mean(),inplace=True)

# %%
df2['Fare'].isnull().sum()
# Out:
# 0

# %%
df.Cabin.isnull().sum()
# Out:
# 687

# %%
df2.Cabin.isnull().sum()
# Out:
# 327

# %%
df.Cabin.fillna('M',inplace=True)

# %%
df2.Cabin.fillna('M',inplace=True)

# %%
df2.Cabin.isnull().sum()
# Out:
# 0

# %%
df.Embarked.fillna(df.Embarked.mode()[0],inplace=True)

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 416          417         1       2
# 53            54         1       2
# 335          336         0       3
# 83            84         0       1
# 284          285         0       1
# 766          767         0       1
# 586          587         0       2
# 383          384         1       1
# 735          736         0       3
# 270          271         0       1
# 570          571         1       2
# 2              3         1       3
# 667          668         0       3
# 353          354         0       3
# 47            48         1       3
# 710          711         1       1
# 578          579         0       3
# 292          293         0       2
# 680          681         0       3
# 842          843         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 416    Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
# ...

# %%
df3 = df.copy()

# %%
df3.Embarked.unique()
data = [df3,df2]

# %%
embarked_mapping = {"S": 0, "C": 1, "Q": 2}
for dataset in data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %%
df3.shape,df2.shape
# Out:
# ((891, 12), (418, 11))

# %%
df4 = df3.copy()

# %%
df4.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  24.0      0
# ...

# %%
df3.Sex = np.where(df3.Sex=='male',1,0)

# %%
df2.Sex = np.where(df2.Sex=='male',1,0)

# %%
data = [df3,df2]

# %%
for dataset in data:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0,
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1,
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2,
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3,
    dataset.loc[ dataset['Age'] > 62, 'Age'] = 4

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  1.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  3.0      1      0
# 2                             Heikkinen, Miss. Laina    0  1.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  2.0      1      0
# 4                           Allen, Mr. William Henry    1  2.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500     M         0
# 1          PC 17599  71.2833   C85         1
# 2  STON/O2. 3101282   7.9250     M         0
# 3            113803  53.1000  C123         0
# 4            373450   8.0500     M         0

# %%
df2.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#    Age  SibSp  Parch   Ticket     Fare Cabin  Embarked
# 0  2.0      0      0   330911   7.8292     M         2
# 1  3.0      1      0   363272   7.0000     M         0
# 2  3.0      0      0   240276   9.6875     M         2
# 3  2.0      0      0   315154   8.6625     M         0
# 4  1.0      1      1  3101298  12.2875     M         0

# %%
df3.Cabin = df3.Cabin.str[0]

# %%
df2.Cabin = df2.Cabin.str[0]

# %%
df3.Cabin.value_counts()
# Out:
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin, dtype: int64

# %%
df2.Cabin.value_counts()
# Out:
# M    327
# C     35
# B     18
# D     13
# E      9
# F      8
# A      7
# G      1
# Name: Cabin, dtype: int64

# %%
d = {'M':9,'C':8,'B':7,'D':6,'E':5,'A':4,'F':3,'G':2,'T':1}

# %%
df3.Cabin = df3.Cabin.map(d)

# %%
df2.Cabin = df2.Cabin.map(d)

# %%
df2.Cabin.isnull().sum()
# Out:
# 0

# %%
df4 = df3.copy()

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  1.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  3.0      1      0
# 2                             Heikkinen, Miss. Laina    0  1.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  2.0      1      0
# 4                           Allen, Mr. William Henry    1  2.0      0      0
#
#              Ticket     Fare  Cabin  Embarked
# 0         A/5 21171   7.2500      9         0
# 1          PC 17599  71.2833      8         1
# 2  STON/O2. 3101282   7.9250      9         0
# 3            113803  53.1000      8         0
# 4            373450   8.0500      9         0

# %%
data = [df4,df2]
for dataset in data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
for dataset in data:
    dataset.drop('Name',axis=1,inplace=True)

# %%
df2.head()
# Out:
#    PassengerId  Pclass  Sex  Age  SibSp  Parch   Ticket     Fare  Cabin  \
# 0          892       3    1  2.0      0      0   330911   7.8292      9
# 1          893       3    0  3.0      1      0   363272   7.0000      9
# 2          894       2    1  3.0      0      0   240276   9.6875      9
# 3          895       3    1  2.0      0      0   315154   8.6625      9
# 4          896       3    0  1.0      1      1  3101298  12.2875      9
#
#    Embarked Title
# 0         2    Mr
# 1         0   Mrs
# 2         2    Mr
# 3         0    Mr
# 4         0   Mrs

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for dataset in data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  1.0      1      0         A/5 21171
# 1            2         1       1    0  3.0      1      0          PC 17599
# 2            3         1       3    0  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  2.0      1      0            113803
# 4            5         0       3    1  2.0      0      0            373450
#
#       Fare  Cabin  Embarked  Title
# 0   7.2500      9         0      0
# 1  71.2833      8         1      2
# 2   7.9250      9         0      1
# 3  53.1000      8         0      2
# 4   8.0500      9         0      0

# %%
for dataset in data:
    dataset.loc[ dataset['Fare'] <= 17, 'Fare'] = 0,
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1,
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2,
    dataset.loc[ dataset['Fare'] > 100, 'Fare'] = 3

# %%
df2.head()
# Out:
#    PassengerId  Pclass  Sex  Age  SibSp  Parch   Ticket  Fare  Cabin  \
# 0          892       3    1  2.0      0      0   330911   0.0      9
# 1          893       3    0  3.0      1      0   363272   0.0      9
# 2          894       2    1  3.0      0      0   240276   0.0      9
# 3          895       3    1  2.0      0      0   315154   0.0      9
# 4          896       3    0  1.0      1      1  3101298   0.0      9
#
#    Embarked  Title
# 0         2      0
# 1         0      2
# 2         2      0
# 3         0      0
# 4         0      2

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  1.0      1      0         A/5 21171
# 1            2         1       1    0  3.0      1      0          PC 17599
# 2            3         1       3    0  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  2.0      1      0            113803
# 4            5         0       3    1  2.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title
# 0   0.0      9         0      0
# 1   2.0      8         1      2
# 2   0.0      9         0      1
# 3   2.0      8         0      2
# 4   0.0      9         0      0

# %%
for dataset in data:
    dataset.drop('Ticket',axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df4.drop('Survived',axis=1)
X.drop('PassengerId',axis=1,inplace=True)

# %%
y = df4['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
x = X.drop('Cabin',axis=1)

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, x, y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())
# Out:
# 0.7968414481897628

# %%
clf = RandomForestClassifier(n_estimators=200)
scoring = 'accuracy'
score = cross_val_score(clf, x, y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())
# Out:
# 0.8137078651685392

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, x, y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())
# Out:
# 0.8058551810237203

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, X, y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())
# Out:
# 0.8103245942571785

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, x, y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())
# Out:
# C:\Users\KRISHNA VAMSI NADH\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KRISHNA VAMSI NADH\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KRISHNA VAMSI NADH\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
0.8249313358302122-0.8204244694132334
# Out:
# 0.004506866416978728

# %%
df2.drop('Cabin',axis=1,inplace=True)

# %%
clf = SVC()
clf.fit(x, y)
test = df2.drop('PassengerId',axis=1).copy()
prediction = clf.predict(test)
# Out:
# C:\Users\KRISHNA VAMSI NADH\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
submission = pd.DataFrame({
        "PassengerId": df2["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission2.csv', index=False)

# %%
sub = pd.read_csv('submission.csv')

# %%
sub.head(10)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
# 5          897         0
# 6          898         1
# 7          899         0
# 8          900         1
# 9          901         0
